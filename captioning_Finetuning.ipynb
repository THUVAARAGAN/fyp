# %% [markdown]
# <a href="https://colab.research.google.com/github/THUVAARAGAN/fyp/blob/main/captioning_Finetuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image

# %%
image_path = []
caption_path = []
for i in range(1,5):
  path = "/content/drive/MyDrive/Fyp/fine tune sample/image " + str(i) + ".png"
  path1 = "/content/drive/MyDrive/Fyp/fine tune sample/image " + str(i) + ".jpg"
  image = Image.open(path)
  image = image.convert("RGB")  # Ensure the image is in RGB mode
  image.save("/content/drive/MyDrive/Fyp/fine tune sample/image " + str(i) + ".jpg", format="JPEG", quality=90)
  print(path1)
  image_path.append(str(path1))

  capt_path = "/content/drive/MyDrive/Fyp/fine tune sample/document_" + str(i) + ".txt"
  print(capt_path)
  caption_path.append(capt_path)
# Out:
# /content/drive/MyDrive/Fyp/fine tune sample/image 1.jpg
# /content/drive/MyDrive/Fyp/fine tune sample/document_1.txt
# /content/drive/MyDrive/Fyp/fine tune sample/image 2.jpg
# /content/drive/MyDrive/Fyp/fine tune sample/document_2.txt
# /content/drive/MyDrive/Fyp/fine tune sample/image 3.jpg
# /content/drive/MyDrive/Fyp/fine tune sample/document_3.txt
# /content/drive/MyDrive/Fyp/fine tune sample/image 4.jpg
# /content/drive/MyDrive/Fyp/fine tune sample/document_4.txt

# %%
import cv2
import numpy as np

# Read the image
image = cv2.imread('/content/drive/MyDrive/Fyp/fine tune sample/image 1.jpg')

# Convert the image to a NumPy array
image_array = np.array(image)

print("Image shape:", image_array.shape)
# Out:
# Image shape: (512, 767, 3)

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Fyp/fine tune sample/captions.txt", sep=" ")
df.head()
# Out:
#                                   Captions
# 0                                  image 1
# 1  A woman standing next to a brown horse.
# 2  A woman standing next to a brown horse.
# 3      A woman standing on top of a horse.
# 4     A woman is standing next to a horse.

# %%
capt = df["Captions"].tolist()
capt
# Out:
# ['image 1',
#  'A woman standing next to a brown horse.',
#  'A woman standing next to a brown horse.',
#  'A woman standing on top of a horse.',
#  'A woman is standing next to a horse.',
#  'A woman standing next to a brown horse.',
#  'image 2',
#  'A couple of kids sitting on a bench.',
#  'A couple of girls sitting on a bench.',
#  'A little girl sitting on a bench with a cell phone.',
#  'A group of dogs are standing on a table.',
#  'Two children sitting on the ground eating a book.',
#  'image 3',
#  'A dog sitting on top of a wooden bench.',
#  'A dog is sitting on a wooden bench.',
#  'A dog sitting on top of a bench.',
#  'A dog sitting on a bench in a park.',
#  'A dog standing next to a wooden bench.',
#  'image 4',
#  'A couple of dogs are sitting on a bench.',
#  'A man sitting on a bench with a dog.',
#  'A group of dogs are standing on a table.',
#  'Two dogs sitting on a bench in front of a fruit stand.',
#  'Three dogs on a leash sitting under a tent.']

# %%
caption = []
para = []
for i in range(0,24,6):
  caption_list =[]
  print(i)
  print(capt[i])
  if capt[i][0:5] == "image":
    caption_list.append(capt[i+1:i+6])
    print(caption_list)
    para.append(capt[i+1:i+6])

  else:
    continue
    # caption_list.append(capt[i])
  caption.append(caption_list)
# Out:
# 0
# image 1
# [['A woman standing next to a brown horse.', 'A woman standing next to a brown horse.', 'A woman standing on top of a horse.', 'A woman is standing next to a horse.', 'A woman standing next to a brown horse.']]
# 6
# image 2
# [['A couple of kids sitting on a bench.', 'A couple of girls sitting on a bench.', 'A little girl sitting on a bench with a cell phone.', 'A group of dogs are standing on a table.', 'Two children sitting on the ground eating a book.']]
# 12
# image 3
# [['A dog sitting on top of a wooden bench.', 'A dog is sitting on a wooden bench.', 'A dog sitting on top of a bench.', 'A dog sitting on a bench in a park.', 'A dog standing next to a wooden bench.']]
# 18
# image 4
# [['A couple of dogs are sitting on a bench.', 'A man sitting on a bench with a dog.', 'A group of dogs are standing on a table.', 'Two dogs sitting on a bench in front of a fruit stand.', 'Three dogs on a leash sitting under a tent.']]

# %%
capt = df["Captions"].tolist()
capt
# Out:
# ['image 1',
#  'A woman standing next to a brown horse.',
#  'A woman standing next to a brown horse.',
#  'A woman standing on top of a horse.',
#  'A woman is standing next to a horse.',
#  'A woman standing next to a brown horse.',
#  'image 2',
#  'A couple of kids sitting on a bench.',
#  'A couple of girls sitting on a bench.',
#  'A little girl sitting on a bench with a cell phone.',
#  'A group of dogs are standing on a table.',
#  'Two children sitting on the ground eating a book.',
#  'image 3',
#  'A dog sitting on top of a wooden bench.',
#  'A dog is sitting on a wooden bench.',
#  'A dog sitting on top of a bench.',
#  'A dog sitting on a bench in a park.',
#  'A dog standing next to a wooden bench.',
#  'image 4',
#  'A couple of dogs are sitting on a bench.',
#  'A man sitting on a bench with a dog.',
#  'A group of dogs are standing on a table.',
#  'Two dogs sitting on a bench in front of a fruit stand.',
#  'Three dogs on a leash sitting under a tent.']

# %%
import os

# %%
# def save_texts_to_drive(texts, output_dir):
#     for i, text in enumerate(texts):
#         file_name = f"document_{i+1}.txt"
#         file_path = os.path.join(output_dir, file_name)
#         with open(file_path, "w") as file:
#             file.write(text)

# # Example usage
# texts = [str(caption[0][0]), str(caption[1][0]), str(caption[2][0]),str(caption[3][0])]  # Your list of texts
# output_directory = "/content/drive/MyDrive/Fyp/fine tune sample"  # Specify the output directory

# save_texts_to_drive(texts, output_directory)

# %%
caption = []
para = []
for i in range(0,24,6):
  caption_list =[]
  print(i)
  print(capt[i])
  if capt[i][0:5] == "image":
    caption_list.append(capt[i+1:i+6])
    print(caption_list)
    caption.append(capt[i+1:i+6])

  else:
    continue
    # caption_list.append(capt[i])
  # caption.append(caption_list)
# Out:
# 0
# image 1
# [['A woman standing next to a brown horse.', 'A woman standing next to a brown horse.', 'A woman standing on top of a horse.', 'A woman is standing next to a horse.', 'A woman standing next to a brown horse.']]
# 6
# image 2
# [['A couple of kids sitting on a bench.', 'A couple of girls sitting on a bench.', 'A little girl sitting on a bench with a cell phone.', 'A group of dogs are standing on a table.', 'Two children sitting on the ground eating a book.']]
# 12
# image 3
# [['A dog sitting on top of a wooden bench.', 'A dog is sitting on a wooden bench.', 'A dog sitting on top of a bench.', 'A dog sitting on a bench in a park.', 'A dog standing next to a wooden bench.']]
# 18
# image 4
# [['A couple of dogs are sitting on a bench.', 'A man sitting on a bench with a dog.', 'A group of dogs are standing on a table.', 'Two dogs sitting on a bench in front of a fruit stand.', 'Three dogs on a leash sitting under a tent.']]

# %%
caption
# Out:
# [['A woman standing next to a brown horse.',
#   'A woman standing next to a brown horse.',
#   'A woman standing on top of a horse.',
#   'A woman is standing next to a horse.',
#   'A woman standing next to a brown horse.'],
#  ['A couple of kids sitting on a bench.',
#   'A couple of girls sitting on a bench.',
#   'A little girl sitting on a bench with a cell phone.',
#   'A group of dogs are standing on a table.',
#   'Two children sitting on the ground eating a book.'],
#  ['A dog sitting on top of a wooden bench.',
#   'A dog is sitting on a wooden bench.',
#   'A dog sitting on top of a bench.',
#   'A dog sitting on a bench in a park.',
#   'A dog standing next to a wooden bench.'],
#  ['A couple of dogs are sitting on a bench.',
#   'A man sitting on a bench with a dog.',
#   'A group of dogs are standing on a table.',
#   'Two dogs sitting on a bench in front of a fruit stand.',
#   'Three dogs on a leash sitting under a tent.']]

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 45.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 88.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.29.2

# %%
from transformers import GPT2TokenizerFast, ViTImageProcessor, VisionEncoderDecoderModel
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image

# %%
class CustomDataset(Dataset):
    def __init__(self, image_paths, captions, tokenizer, image_processor):
        self.image_paths = image_paths
        self.captions = captions
        self.tokenizer = tokenizer
        self.image_processor = image_processor
    
    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        caption = self.captions[idx]

        # Load and preprocess the image
        image = Image.open(image_path)
        pixel_values = self.image_processor(image, return_tensors="pt").pixel_values.squeeze()

        # Tokenize the caption
        inputs = self.tokenizer(caption, return_tensors="pt", truncation=True, padding="max_length", max_length=128)
        input_ids = inputs.input_ids.squeeze()
        attention_mask = inputs.attention_mask.squeeze()

        return pixel_values, input_ids, attention_mask

# %%
model_raw = VisionEncoderDecoderModel.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
tokenizer = GPT2TokenizerFast.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
image_processor = ViTImageProcessor.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/4.61k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# Downloading (…)rocessor_config.json:   0%|          | 0.00/228 [00:00<?, ?B/s]

# %%
# model_raw = VisionEncoderDecoderModel.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
# model_vit = model_raw.vit
# model_gpt2 = model_raw.gpt2

# %%
dataset = CustomDataset(image_path, caption, tokenizer, image_processor)
batch_size = 1  # Adjust according to your available memory
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model_raw.parameters(), lr=1e-5)
num_epochs = 1

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_raw.to(device)

for epoch in range(num_epochs):
    model_raw.train()
    total_loss = 0

    for pixel_values, input_ids, attention_mask in dataloader:
        pixel_values = pixel_values.to(device)
        print(pixel_values[0].shape)
        
        input_ids = input_ids.to(device)
        attention_mask = attention_mask.to(device)

        optimizer.zero_grad()

        outputs = model_raw(pixel_values=pixel_values, decoder_input_ids=input_ids)
        logits = outputs.logits

        loss = loss_function(logits.view(-1, logits.shape[-1]), input_ids.view(-1))
        total_loss += loss.item()

        loss.backward()
        optimizer.step()

    average_loss = total_loss / len(dataloader)
    print(f"Epoch {epoch+1} - Loss: {average_loss}")
# Out:
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# torch.Size([3, 224, 224])
# Epoch 1 - Loss: 3.4574220776557922

# %%
model_raw.save_pretrained("/content/drive/MyDrive/Fyp/fine tune sample/model")
